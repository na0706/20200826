# %% [markdown]
# <a href="https://colab.research.google.com/github/na0706/20200826/blob/master/collect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install icrawler
# Out:
# Requirement already satisfied: icrawler in /usr/local/lib/python3.6/dist-packages (0.6.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.6.3)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (2.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from icrawler) (7.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.2.6)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from icrawler) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2.10)

# %%
# pathは適宜変える
# %cd drive/My Drive/summer01/original01
# !pwd
# Out:
# /content/drive/My Drive/summer01/original01
# /content/drive/My Drive/summer01/original01

# %%
from icrawler.builtin import BingImageCrawler
crawler = BingImageCrawler(storage={"root_dir": "ishihara"})
crawler.crawl(keyword="石原さとみ", max_num=10)
# Out:
# 2020-08-26 06:10:39,368 - INFO - icrawler.crawler - start crawling...
# 2020-08-26 06:10:39,369 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-08-26 06:10:39,376 - INFO - feeder - thread feeder-001 exit
# 2020-08-26 06:10:39,379 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-08-26 06:10:39,387 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-08-26 06:10:39,768 - INFO - parser - parsing result page https://www.bing.com/images/async?q=石原さとみ&first=0
# 2020-08-26 06:10:40,874 - INFO - downloader - image #1	http://xn--zck8ci9591bzonbkq1xt.com/wp-content/uploads/2017/01/ishiharasatomi-141-a.jpg
# 2020-08-26 06:10:42,228 - INFO - downloader - image #2	http://lineofficial.blogimg.jp/ja/imgs/9/0/90eb5a7f.jpg
# 2020-08-26 06:10:44,272 - INFO - downloader - image #3	https://matome.aa-beauty.com/wp-content/uploads/2019/02/t32gog8.jpg
# 2020-08-26 06:10:44,558 - INFO - downloader - image #4	http://2.bp.blogspot.com/-K7FMwGaV2ko/TbaEomFjnjI/AAAAAAAAD1s/i9ao9p9Lefg/s1600/64.jpg
# 2020-08-26 06:10:45,931 - INFO - downloader - image #5	https://yumeijinhensachi.com/wp-content/uploads/2016/12/59885adf404a464456f2195fe1aa2f30.jpg
# 2020-08-26 06:10:46,652 - INFO - downloader - image #6	http://blog-imgs-79.fc2.com/t/a/k/takarabakovan/isihara7.jpg
# 2020-08-26 06:10:47,322 - INFO - downloader - image #7	https://i.pinimg.com/originals/8e/cd/02/8ecd024a5eedb5f650a4a39363f9153f.jpg
# 2020-08-26 06:10:48,681 - INFO - downloader - image #8	https://2xmlabs.com/wp-content/uploads/2018/02/37731719.jpg
# 2020-08-26 06:10:48,925 - INFO - downloader - image #9	https://i.pinimg.com/originals/a5/f4/c2/a5f4c2571dab0106022ddc9992b150b1.jpg
# 2020-08-26 06:10:50,562 - INFO - downloader - image #10	http://static-maquia.hpplus.jp/upload/image/manager/25/F3kpZUA-1200.jpg
# 2020-08-26 06:10:51,763 - INFO - downloader - downloaded images reach max num, thread downloader-001 is ready to exit
# 2020-08-26 06:10:51,764 - INFO - downloader - thread downloader-001 exit
# 2020-08-26 06:10:52,404 - INFO - icrawler.crawler - Crawling task done!

# %%
from icrawler.builtin import BingImageCrawler
crawler = BingImageCrawler(storage={"root_dir": "kubota"})
crawler.crawl(keyword="窪田正孝", max_num=10)
# Out:
# 2020-08-26 06:12:59,461 - INFO - icrawler.crawler - start crawling...
# 2020-08-26 06:12:59,461 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-08-26 06:12:59,463 - INFO - feeder - thread feeder-001 exit
# 2020-08-26 06:12:59,464 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-08-26 06:12:59,469 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-08-26 06:12:59,858 - INFO - parser - parsing result page https://www.bing.com/images/async?q=窪田正孝&first=0
# 2020-08-26 06:13:01,297 - INFO - downloader - image #1	https://img.cinematoday.jp/a/N0097688/_size_1200x/_v_1516165391/main.jpg
# 2020-08-26 06:13:01,394 - INFO - downloader - image #2	https://pbs.twimg.com/profile_images/799450061855784961/X1GA6ygo.jpg
# 2020-08-26 06:13:01,775 - INFO - downloader - image #3	https://i.pinimg.com/originals/d2/bb/a7/d2bba71a0599150fbbcaaf01444fd29a.jpg
# 2020-08-26 06:14:57,712 - INFO - parser - downloaded image reached max num, thread parser-001 is ready to exit
# 2020-08-26 06:14:57,713 - INFO - parser - thread parser-001 exit

# %%
import cv2
import matplotlib.pyplot as plt
import sys
from keras.preprocessing.image import array_to_img,img_to_array,load_img
import numpy as np
import os

cascade_path="/content/drive/My Drive/summer01/haarcascade_frontalface_alt (2).xml"

X_train=[]
Y_train=[]

X_test=[]
Y_test=[]
Mydribe = "/content/drive/My Drive/summer01"

l=os.listdir(Mydribe + "/original01")

# %%
# https://github.com/opencv/opencv/tree/master/data/haarcascades
# https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_alt.xml


for i in l:
    result_dir=i.split(".")[0]
    print(result_dir)
    # os.mkdir(Mydribe + "/face/"+result_dir)
    os.makedirs(Mydribe + "/face/"+result_dir, exist_ok=True)

    m=os.listdir(Mydribe + "/original01/"+i)
    n=0
    for target_file in m:
        origin_image=(Mydribe + "/original01/"+i+"/"+target_file)
        print(origin_image)
        cascade=cv2.CascadeClassifier(cascade_path)
        image=cv2.imread(origin_image)

        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        gray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
        plt.imshow(gray)

        facerect=cascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=1,minSize=(10,10))

        for x,y,w,h in facerect:
            face=gray[y:y+h,x:x+w]
            face=cv2.resize(face,(128,128))
            save_path=Mydribe + "/face/"+result_dir+"/image_"+str(n)+".jpg"
            cv2.imwrite(save_path,face)
            n=n+1
            face=cv2.flip(face,1)
            save_path=Mydribe + "/face/"+result_dir+"/image_"+str(n)+".jpg"
            cv2.imwrite(save_path,face)
            n=n+1
            face=cv2.blur(face,(10,10))
            save_path=Mydribe + "/face/"+result_dir+"/image_"+str(n)+".jpg"
            cv2.imwrite(save_path,face)
            n=n+1
            face=cv2.blur(cv2.flip(face,1),(10,10))
            save_path=Mydribe + "/face/"+result_dir+"/image_"+str(n)+".jpg"
            cv2.imwrite(save_path,face)
            n=n+1
# Out:
# naganomei
# /content/drive/My Drive/summer01/original01/naganomei/000004.jpg
# /content/drive/My Drive/summer01/original01/naganomei/000005.jpg
# /content/drive/My Drive/summer01/original01/naganomei/000006.jpg
# /content/drive/My Drive/summer01/original01/naganomei/000008.jpg
# /content/drive/My Drive/summer01/original01/naganomei/000009.jpg
# ishihara
# /content/drive/My Drive/summer01/original01/ishihara/000004.jpg
# /content/drive/My Drive/summer01/original01/ishihara/000005.jpg
# /content/drive/My Drive/summer01/original01/ishihara/000006.jpg
# /content/drive/My Drive/summer01/original01/ishihara/000007.jpg
# /content/drive/My Drive/summer01/original01/ishihara/000008.jpg
# /content/drive/My Drive/summer01/original01/ishihara/000009.jpg
# /content/drive/My Drive/summer01/original01/ishihara/000010.jpg
# kubota
# /content/drive/My Drive/summer01/original01/kubota/000004.jpg
# /content/drive/My Drive/summer01/original01/kubota/000005.jpg
# /content/drive/My Drive/summer01/original01/kubota/000006.jpg
# /content/drive/My Drive/summer01/original01/kubota/000007.jpg
# /content/drive/My Drive/summer01/original01/kubota/000008.jpg
# /content/drive/My Drive/summer01/original01/kubota/000009.jpg
# /content/drive/My Drive/summer01/original01/kubota/000010.jpg
# test
# /content/drive/My Drive/summer01/original01/test/000001.jpg
# /content/drive/My Drive/summer01/original01/test/000002.jpg
# /content/drive/My Drive/summer01/original01/test/000003.jpg
# /content/drive/My Drive/summer01/original01/test/000001 (2).jpg
# /content/drive/My Drive/summer01/original01/test/000002 (2).jpg
# /content/drive/My Drive/summer01/original01/test/000003 (2).jpg
# /content/drive/My Drive/summer01/original01/test/000001 (1).jpg
# /content/drive/My Drive/summer01/original01/test/000002 (1).jpg
# /content/drive/My Drive/summer01/original01/test/000003 (1).jpg
# content
# /content/drive/My Drive/summer01/original01/content/.ipynb_checkpoints
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-31-a7dfd79d235f> in <module>()
#      17         image=cv2.imread(origin_image)
#      18
# ---> 19         image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
#      20         gray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
#      21         plt.imshow(gray)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
